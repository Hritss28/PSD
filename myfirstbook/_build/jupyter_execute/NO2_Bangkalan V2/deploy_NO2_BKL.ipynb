# %% [markdown]
# ## **Deployment Prediksi Kadar NO₂ di Kabupaten Bangkalan**

# %% [markdown]
# Disini Untuk Deployment saya menggunakan streamlit. Untuk Prediksi Kadar NO₂ di Kabupaten Bangkalan dapat di akses melalui link berikut ini: https://forecasting-no2-korelasi.streamlit.app/

# %% [markdown]
# ### ***Tampilan Website Deployment***

# %% [markdown]
# ![Tampilan Website Deployment](./deployment-prediksi.png)

# %% [markdown]
# ### ***Code Program Deploy***

# %%
import streamlit as st
import pandas as pd
import joblib

@st.cache_resource
def load_model_and_features(model_type):
    if model_type == "1_hari":
        model = joblib.load('saved_models/knn_model_day2_filtered.pkl')
        scaler = joblib.load('saved_models/scaler_day2_filtered.pkl')
        sample_data = pd.read_csv('no2_results/day2_supervised_filtered.csv')
        features = [col for col in sample_data.columns if col.startswith('t-')]
    else:  # 3_hari
        model = joblib.load('saved_models/knn_model_day1_filtered.pkl')
        scaler = joblib.load('saved_models/scaler_day1_filtered.pkl')
        sample_data = pd.read_csv('no2_results/day1_supervised_filtered.csv')
        features = [col for col in sample_data.columns if col.startswith('t-')]
    return model, scaler, features

@st.cache_data
def load_thresholds():
    return joblib.load('saved_models/thresholds_day3.pkl')

st.set_page_config(page_title="Prediksi NO₂ Bangkalan", page_icon="🌫️")
st.title("🌫️ Prediksi Kadar NO₂ - Bangkalan")
st.caption("Prediksi kadar NO₂ troposfer (mol/m²) menggunakan model KNN berdasarkan data Sentinel-5P.")

# Pilihan model prediksi
prediksi_type = st.radio(
    "Pilih Jenis Prediksi:",
    ("1_hari", "3_hari"),
    format_func=lambda x: "Prediksi 1 Hari Ke Depan" if x == "1_hari" else "Prediksi 3 Hari Ke Depan",
    horizontal=True
)

model, scaler, features = load_model_and_features(prediksi_type)
thresholds = load_thresholds()

def get_kategori(nilai):
    """Kategorisasi berdasarkan threshold"""
    if nilai <= thresholds['low']:
        return "🟢 **RENDAH**", "Kadar NO₂ rendah, kualitas udara baik."
    elif nilai <= thresholds['medium']:
        return "🟡 **SEDANG**", "Kadar NO₂ sedang, masih dalam batas aman."
    else:
        return "🔴 **TINGGI**", "Kadar NO₂ tinggi, waspadai kualitas udara!"

# Tampilkan features yang digunakan
st.info(f"📊 **Model {prediksi_type.title()}**: Menggunakan features: {', '.join(features)}")

# Input
input_values = {}
cols = st.columns(len(features))

for i, feature in enumerate(features):
    with cols[i]:
        input_values[feature] = st.number_input(
            f"NO₂ Hari Ini ({feature})", 
            value=0.000030, 
            format="%.6f",
            help=f"Data NO₂ pada waktu {feature}"
        )

if st.button("Prediksi", type="primary"):
    X = pd.DataFrame([input_values])[features]
    X_scaled = scaler.transform(X)
    
    y_pred = model.predict(X_scaled)[0]
    
    st.success("### Hasil Prediksi")
    
    if isinstance(y_pred, (list, tuple)) or (hasattr(y_pred, 'shape') and len(y_pred.shape) > 0 and y_pred.shape[0] > 1):
        # Multi-output
        num_predictions = len(y_pred)
        cols = st.columns(num_predictions)
        
        for i in range(num_predictions):
            with cols[i]:
                nilai_molm2 = y_pred[i]
                kategori, keterangan = get_kategori(nilai_molm2)
                
                st.metric(f"NO₂ Hari ke {i+1} (t+{i+1})", f"{nilai_molm2:.6f} mol/m²")
                st.markdown(kategori)
                st.caption(keterangan)
    else:
        # Single output
        nilai_molm2 = float(y_pred)
        kategori, keterangan = get_kategori(nilai_molm2)
        
        st.metric("NO₂ Hari Besok (t+1)", f"{nilai_molm2:.6f} mol/m²")
        st.markdown(kategori)
        st.caption(keterangan)

with st.expander("📋 Informasi Model & Threshold"):
    st.markdown(f"""
    **Features yang Digunakan**: {', '.join(features)}
    
    **Alasan Pemilihan**: Berdasarkan analisis korelasi ≥ 50% dengan target
    """)
    
    st.markdown(f"""    
    **Kategori Kadar NO₂:**
    - 🟢 **RENDAH**: ≤ {thresholds['low']:.6f} mol/m²
    - 🟡 **SEDANG**: {thresholds['low']:.6f} - {thresholds['medium']:.6f} mol/m²
    - 🔴 **TINGGI**: > {thresholds['medium']:.6f} mol/m²
    
    **Statistik Data:**
    - Minimum: {thresholds['min']:.6f} mol/m²
    - Maksimum: {thresholds['max']:.6f} mol/m²
    - Rata-rata: {thresholds['mean']:.6f} mol/m²
    """)

st.divider()
st.caption("Model: KNN Regression berdasarkan analisis korelasi | Data: 268 observasi | Metode Threshold: Quartile")
# Out:
# 2025-11-17 10:34:17.684 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-11-17 10:34:17.756 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:17.759 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.557
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Python311\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-17 10:34:18.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.569 Session state does not function when running a script without `streamlit run`
# 2025-11-17 10:34:18.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:18.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:19.084 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:19.091 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:19.094 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:20.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:20.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:20.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:20.044 No runtime found, using MemoryCacheStorageManager
# 2025-11-17 10:34:20.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:20.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:20.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:20.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:20.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:20.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-17 10:34:20.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 36
#      28 prediksi_type = st.radio(
#      29     "Pilih Jenis Prediksi:",
#      30     ("1_hari", "3_hari"),
#      31     format_func=lambda x: "Prediksi 1 Hari Ke Depan" if x == "1_hari" else "Prediksi 3 Hari Ke Depan",
#      32     horizontal=True
#      33 )
#      35 model, scaler, features = load_model_and_features(prediksi_type)
# ---> 36 thresholds = load_thresholds()
#      38 def get_kategori(nilai):
#      39     """Kategorisasi berdasarkan threshold"""
#
# File C:\Python311\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:227, in CachedFunc.__call__(self, *args, **kwargs)
#     224     else:
#     225         spinner_message = f"Running `{name}(...)`."
# --> 227 return self._get_or_create_cached_value(args, kwargs, spinner_message)
#
# File C:\Python311\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:269, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs, spinner_message)
#     263 spinner_or_no_context = (
#     264     spinner(spinner_message, _cache=True, show_time=self._info.show_time)
#     265     if spinner_message is not None and not is_nested_cache_function
#     266     else contextlib.nullcontext()
#     267 )
#     268 with spinner_or_no_context:
# --> 269     return self._handle_cache_miss(cache, value_key, func_args, func_kwargs)
#
# File C:\Python311\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:328, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     324 # We acquired the lock before any other thread. Compute the value!
#     325 with self._info.cached_message_replay_ctx.calling_cached_function(
#     326     self._info.func
#     327 ):
# --> 328     computed_value = self._info.func(*func_args, **func_kwargs)
#     330 # We've computed our value, and now we need to write it back to the cache
#     331 # along with any "replay messages" that were generated during value computation.
#     332 messages = self._info.cached_message_replay_ctx._most_recent_messages
#
# Cell In[1], line 21, in load_thresholds()
#      19 @st.cache_data
#      20 def load_thresholds():
# ---> 21     return joblib.load('saved_models/thresholds_day3.pkl')
#
# File C:\Python311\Lib\site-packages\joblib\numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'saved_models/thresholds_day3.pkl'
