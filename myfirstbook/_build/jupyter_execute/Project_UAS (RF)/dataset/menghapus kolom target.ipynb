# %%
import pandas as pd
df_deploy = pd.read_csv('BME_TEST_DEPLOY.csv')

print(f"Shape sebelum menghapus target: {df_deploy.shape}")
print(f"Kolom: {df_deploy.columns.tolist()}")

df_deploy_no_target = df_deploy.drop('target', axis=1)

print(f"\nShape setelah menghapus target: {df_deploy_no_target.shape}")
print(f"Kolom: {df_deploy_no_target.columns.tolist()}")

df_deploy_no_target.to_csv('BME_TEST_DEPLOY_NO_TARGET.csv', index=False)
print("\nFile berhasil disimpan sebagai 'dataset/BME_TEST_DEPLOY_NO_TARGET.csv'")
# Out:
# Shape sebelum menghapus target: (142, 129)
# ...
