# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

df_train = pd.read_csv('BME_TEST_DEPLOY.csv')
print("Data Deploy:")
print(df_train['target'].value_counts(). sort_index())
# Out:
# Data Deploy:
# target
# 1    47
# 2    47
# 3    48
# Name: count, dtype: int64
